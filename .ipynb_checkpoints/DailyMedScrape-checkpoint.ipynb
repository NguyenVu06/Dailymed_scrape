# %%
from selenium import webdriver
import pandas as pd
import time
import re

try:
    raw_data = {'name': ['name'],
                'company': ['company'],
                'com1': ['com1'],
                'com1_con': ['com1_con'],
                'com2': ['com2'],
                'com2_con': ['com2_con'],
                'com3': ['com3'],
                'com3_con': ['com3_con'],
                'com4': ['com4'],
                'com4_con': ['com4_con'],
                'com5': ['com5'],
                'com5_con': ['com5_con'],
                'ph': ['ph'],
                'dosage': ['dosage']
                }
    print('--', raw_data)
    df = pd.DataFrame(raw_data,
                      columns=['name', 'company', 'com1', 'com1_con',
                               'com2', 'com2_con', 'com3', 'com3_con', 'com4', 'com4_con', 'com5',
                               'com5_con', 'ph', 'dosage'])
    df.to_csv('Result.csv', mode='a', header=False, index=False)

except Exception as ex:
    print(ex)
    
def getdata(txt, reg):
    com1 = ''
    com1_con = ''
    com2 = ''
    com2_con = ''
    matchs = re.findall(reg, txt)
    if matchs:
        if 'oil' in reg:
            com1_con = matchs[0].replace('oil ', '')
            ss = txt.split(matchs[0])
            ss = ss[0].strip().split(' ')
            com1 = ss[-1] + ' oil'
        elif 'benz' in reg:
            com1_con = matchs[0].split('(')[1]
            com1 = matchs[0].split('(')[0]
            if len(matchs) > 1:
                com2_con = matchs[1].split('(')[1]
                com2 = matchs[1].split('(')[0]
        else:
            com1_con = matchs[0].split('(')[1]
            com1 = matchs[0].split('(')[0]
        com1_con = com1_con.replace('(', '').replace(')', '')
        com2_con = com2_con.replace('(', '').replace(')', '')

    if 'benz' in reg:
        return com1, com2, com1_con, com2_con
    return com1, com1_con


oil_reg = 'oil \(.*?\)'
gly_reg = 'glycer\w+ \(.*?\)'
egg_reg = 'egg \w+ \(.*?\)'
benz_reg = 'benz\w+ \w+ \(.*?\)|\w+ benz\w+ \(.*?\)'

url = 'https://dailymed.nlm.nih.gov/dailymed/search.cfm?labeltype=all&query=propofol&pagesize=200&page=1'
browser = webdriver.Chrome(executable_path='/Users/nguyendvu/Documents/ODP/DrugInfoWebscrape/chromedriver')
browser.get(url)
browser.implicitly_wait(10)
articles = browser.find_elements_by_xpath("//div[@class='results']/article")

urls = []
for article in articles:
    url = article.find_element_by_class_name('drug-info-link').get_attribute('href')
    urls.append(url)

for url in urls:
    try:
        browser.get(url)
        browser.implicitly_wait(10)
        name = ''
        name = browser.find_element_by_id('drug-label').text
        company = ''
        company = browser.find_element_by_xpath("//ul[@class='drug-information'][1]/li[2]").text.replace('Packager: ', '')
        
        browser.find_element_by_id('anch_dj_109').click()
        time.sleep(1)
        
        li_tags = browser.find_elements_by_xpath("//div[@id='drug-information']/div["
                                                 "@class='drug-label-sections']/ul/li")
        dosage = ''
        com1 = ''
        com1_con = ''
        com2 = ''
        com2_con = ''
        com3 = ''
        com3_con = ''
        com4 = ''
        com4_con = ''
        com5 = ''
        com5_con = ''
        ph = ''
        for li_tag in li_tags:
            txt = li_tag.text
            if 'DESCRIPTION' in txt:
                com1, com1_con = getdata(txt, oil_reg)
                com2, com2_con = getdata(txt, gly_reg)
                com3, com3_con = getdata(txt, egg_reg)
                com4, com5, com4_con, com5_con = getdata(txt, benz_reg)
                ph = txt.split('a pH of ')[-1]
                break
        for li_tag in li_tags:
            txt = li_tag.text
            if 'SUMMARY OF DOSAGE GUIDELINES' in txt:
                tables = li_tag.find_elements_by_tag_name('table')
                for table in tables:
                    trs = table.find_elements_by_tag_name('tr')
                    for tr in trs:
                        if 'Induction of General Anesthesia' in tr.text:
                            tds = tr.find_elements_by_tag_name('td')
                            td1_txt = tds[0].text
                            td2_txt = tds[1].text
                            if 'Induction of General Anesthesia' in td1_txt:
                                dosage = td2_txt
                                break
        try:
            raw_data = {'name': [name],
                        'company': [company],
                        'com1': [com1],
                        'com1_con': [com1_con],
                        'com2': [com2],
                        'com2_con': [com2_con],
                        'com3': [com3],
                        'com3_con': [com3_con],
                        'com4': [com4],
                        'com4_con': [com4_con],
                        'com5': [com5],
                        'com5_con': [com5_con],
                        'ph': [ph],
                        'dosage': [dosage]
                            }
            print('--', raw_data)
            df = pd.DataFrame(raw_data,
                              columns=['name', 'company', 'com1', 'com1_con',
                                       'com2', 'com2_con', 'com3', 'com3_con', 'com4', 'com4_con', 'com5',
                                       'com5_con', 'ph', 'dosage'])
            df.to_csv('Result.csv', mode='a', header=False, index=False)

        except Exception as ex:
            print(ex)
    except Exception as ex:
        print(ex)

browser.quit()
# Out:
# -- {'name': ['name'], 'company': ['company'], 'com1': ['com1'], 'com1_con': ['com1_con'], 'com2': ['com2'], 'com2_con': ['com2_con'], 'com3': ['com3'], 'com3_con': ['com3_con'], 'com4': ['com4'], 'com4_con': ['com4_con'], 'com5': ['com5'], 'com5_con': ['com5_con'], 'ph': ['ph'], 'dosage': ['dosage']}
# -- {'name': ['PROPOFOL INJECTABLE EMULSION injection, emulsion'], 'company': ["Dr. Reddy's Laboratories, Inc."], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg phospholipids '], 'com3_con': ['12 mg/mL'], 'com4': ['benzyl alcohol '], 'com4_con': ['0.15%'], 'com5': [''], 'com5_con': [''], 'ph': ['5.5 to 7.4.\nCLOSE'], 'dosage': ['Healthy Adults Less Than 55 Years of Age:  40 mg every 10 seconds until induction onset (2 mg/kg to 2.5 mg/kg). Elderly, Debilitated, or ASA-PS III or IV Patients:  20 mg every 10 seconds until induction onset (1 mg/kg to 1.5 mg/kg).']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['Actavis Pharma, Inc.'], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerin '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg phospholipids '], 'com3_con': ['12 mg/mL'], 'com4': ['sodium benzoate '], 'com4_con': ['0.1%'], 'com5': [''], 'com5_con': [''], 'ph': ['6.0 to 8.5.\nCLOSE'], 'dosage': ['  Healthy Adults Less Than 55 Years of Age:\n40 mg every 10 seconds until induction onset (2 mg/kg to 2.5 mg/kg).\nElderly, Debilitated, or ASA-PS III or IV Patients:\n20 mg every 10 seconds until induction onset (1 mg/kg to 1.5 mg/kg).\nCardiac Anesthesia:\n20 mg every 10 seconds until induction onset (0.5 mg/kg to 1.5 mg/kg).\nNeurosurgical Patients:\n20 mg every 10 seconds until induction onset (1 mg/kg to 2 mg/kg).\nPediatric Patients - healthy, from 3 years to 16 years of age:\n2.5 mg/kg to 3.5 mg/kg administered over 20 seconds to 30 seconds. (see PRECAUTIONS, PEDIATRIC USE and CLINICAL PHARMACOLOGY, Pediatrics)']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['Hikma Pharmaceuticals USA Inc.'], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg lecithin '], 'com3_con': ['12 mg/mL'], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['6.5 to 8.5.\nCLOSE'], 'dosage': ['Healthy Adults Less Than 55 Years of Age:\n40 mg every 10 seconds until induction onset (2 mg/kg to 2.5 mg/kg)\nElderly, Debilitated, or ASA-PS III or IV Patients: \n20 mg every 10 seconds until induction onset (1 mg/kg to 1.5 mg/kg).\nCardiac Anesthesia: \n20 mg every 10 seconds until induction onset (0.5 mg/kg to 1.5 mg/kg).\nNeurosurgical Patients: \n20 mg every 10 seconds until induction onset (1 mg/kg to 2 mg/kg).\nPediatric Patients - healthy, from 3 years to 16 years of age: \n2.5 mg/kg to 3.5 mg/kg administered over 20 seconds to 30 seconds.\n(see PRECAUTIONS, PEDIATRIC USE and CLINICAL PHARMACOLOGY, PEDIATRICS:)']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['Hospira, Inc.'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol injectable emulsion is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is chemically described as 2,6-diisopropylphenol ...'], 'dosage': ['']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['Pfizer Laboratories Div Pfizer Inc'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol Injectable Emulsion, USP is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is chemically described as ...'], 'dosage': ['']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['Sagent Pharmaceuticals'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol injectable emulsion, USP is a sterile, nonpyrogenic emulsion containing 10 mg per mL of propofol, USP suitable for intravenous administration. Propofol, USP is chemically described as 2 ...'], 'dosage': ['']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['A-S Medication Solutions'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol Injectable Emulsion, USP is a white or almost white sterile, nonpyrogenic homogenous emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is ...'], 'dosage': ['']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['General Injectables & Vaccines, Inc.'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol Injectable Emulsion, USP is a white or almost white sterile, nonpyrogenic homogenous emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is ...'], 'dosage': ['']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['General Injectables and Vaccines, Inc'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol injection emulsion is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is chemically described as 2,6-diisopropylphenol ...'], 'dosage': ['']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['HF Acquisition Co LLC, DBA HealthFirst'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol injectable emulsion is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is chemically described as 2,6-diisopropylphenol ...'], 'dosage': ['']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['HF Acquisition Co LLC, DBA HealthFirst'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol Injectable Emulsion, USP is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is chemically described as ...'], 'dosage': ['']}
# -- {'name': ['PROPOFOL injection, emulsion'], 'company': ['HF Acquisition Co LLC, DBA HealthFirst'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nPropofol Injectable Emulsion, USP is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is chemically described as ...'], 'dosage': ['']}
# -- {'name': ['ANESTHESIA S/I-40- propofol, isopropyl alcohol kit'], 'company': ['RX PHARMA-PACK, INC.'], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg lecithin '], 'com3_con': ['12 mg/mL'], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['7 to 8.5.\nCLOSE'], 'dosage': ['Healthy Adults Less Than 55 Years of Age:\n40 mg every 10 seconds until induction onset (2 mg/kg to 2.5 mg/kg).\nElderly, Debilitated, or ASA-PS III or IV Patients: 20 mg every 10 seconds until induction onset (1 mg/kg to 1.5 mg/kg).\nCardiac Anesthesia:\n20 mg every 10 seconds until induction onset (0.5 mg/kg to 1.5 mg/kg).\nNeurosurgical Patients:\n20 mg every 10 seconds until induction onset (1 mg/kg to 2 mg/kg).\nPediatric Patients - healthy, from 3 years to 16 years of age:\n2.5 mg/kg to 3.5 mg/kg administered over 20 seconds to 30 seconds. (see PRECAUTIONS, Pediatric Use and CLINICAL PHARMACOLOGY, Pediatrics).']}
# -- {'name': ['ANESTHESIA S/I-60- propofol, sterile isopropyl alcohol kit'], 'company': ['RX PHARMA-PACK, INC.'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION\nDIPRIVAN® (Propofol)  Injectable Emulsion,  USP is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration. Propofol is chemically described as ...'], 'dosage': ['']}
# -- {'name': ['DIPRIVAN- propofol injection, emulsion'], 'company': ['Fresenius Kabi USA, LLC'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION:\nDIPRIVAN® (propofol) injectable emulsion, USP is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration.  Propofol is chemically described as ...'], 'dosage': ['']}
# -- {'name': ['DIPRIVAN- propofol injection, emulsion'], 'company': ['Fresenius Kabi USA, LLC'], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg lecithin '], 'com3_con': ['12 mg/mL'], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['7 to 8.5.\nCLOSE'], 'dosage': ['Healthy Adults Less Than 55 Years of Age:\n40 mg every 10 seconds until induction onset (2 mg/kg to 2.5 mg/kg).\nElderly, Debilitated, or ASA-PS III or IV Patients:\n20 mg every 10 seconds until induction onset (1 mg/kg to 1.5 mg/kg).\nCardiac Anesthesia:\n20 mg every 10 seconds until induction onset (0.5 mg/kg to 1.5 mg/kg).\nNeurosurgical Patients:\n20 mg every 10 seconds until induction onset (1 mg/kg to 2 mg/kg).\nPediatric Patients - healthy, from 3 years to 16 years of age:\n2.5 mg/kg to 3.5 mg/kg administered over 20 seconds to 30 seconds. (see PRECAUTIONS, PEDIATRIC USE and CLINICAL PHARMACOLOGY, PEDIATRICS).']}
# -- {'name': ['DIPRIVAN- propofol injection, emulsion'], 'company': ['Fresenius Kabi USA, LLC'], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg lecithin '], 'com3_con': ['12 mg/mL'], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['7 to 8.5.\nCLOSE'], 'dosage': ['Healthy Adults Less Than 55 Years of Age:\n40 mg every 10 seconds until induction onset (2 mg/kg to 2.5 mg/kg).\nElderly, Debilitated, or ASA-PS III or IV Patients:\n20 mg every 10 seconds until induction onset (1 mg/kg to 1.5 mg/kg).\nCardiac Anesthesia:\n20 mg every 10 seconds until induction onset (0.5 mg/kg to 1.5 mg/kg).\nNeurosurgical Patients:\n20 mg every 10 seconds until induction onset (1 mg/kg to 2 mg/kg).\nPediatric Patients - healthy, from 3 years to 16 years of age:\n2.5 mg/kg to 3.5 mg/kg administered over 20 seconds to 30 seconds. (see PRECAUTIONS, PEDIATRIC USE and CLINICAL PHARMACOLOGY, PEDIATRICS).']}
# -- {'name': ['DIPRIVAN- propofol injection, emulsion'], 'company': ['Fresenius Kabi USA, LLC'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION:\nDIPRIVAN® (propofol) injectable emulsion, USP is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration.  Propofol is chemically described as ...'], 'dosage': ['']}
# -- {'name': ['DIPRIVAN- propofol injection, emulsion'], 'company': ['Fresenius Kabi USA, LLC'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION:\nDIPRIVAN® (propofol) injectable emulsion, USP is a sterile, nonpyrogenic emulsion containing 10 mg/mL of propofol suitable for intravenous administration.  Propofol is chemically described as ...'], 'dosage': ['']}
# -- {'name': ['FRESENIUS PROPOVEN 2%- propofol emulsion'], 'company': ['Fresenius Kabi Austria GmbH'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': [''], 'dosage': ['']}
# -- {'name': ['FRESENIUS PROPOVEN 2%- propofol emulsion'], 'company': ['Fresenius Kabi USA, LLC'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': [''], 'dosage': ['']}
# -- {'name': ['PROPOFLO- propofol injection, emulsion'], 'company': ['Zoetis Inc.'], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg lecithin '], 'com3_con': ['12 mg/mL'], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['6.0-9.0.'], 'dosage': ['']}
# -- {'name': ['PROPOFLO 28- propofol injection, emulsion'], 'company': ['Zoetis Inc.'], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg lecithin '], 'com3_con': ['12 mg/mL'], 'com4': ['benzyl alcohol '], 'com4_con': ['20 mg/mL'], 'com5': [''], 'com5_con': [''], 'ph': ['6.0-8.5. PropoFlo™ 28 does not meet the propofol injectable emulsion USP specification for free fatty acids.'], 'dosage': ['']}
# -- {'name': ['PROPOTHESIA- propofol injection, emulsion'], 'company': ['Butler Animal Health Supply LLC'], 'com1': ['soybean oil'], 'com1_con': ['100 mg'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg'], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['4.5-6.6.'], 'dosage': ['']}
# -- {'name': ['RAPANOFAL- propofol injection, emulsion'], 'company': ['Ivaoes, Llc'], 'com1': [''], 'com1_con': [''], 'com2': [''], 'com2_con': [''], 'com3': [''], 'com3_con': [''], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['DESCRIPTION'], 'dosage': ['']}
# -- {'name': ['DIPRIVAN injection, emulsion'], 'company': ['General Injectables & Vaccines, Inc'], 'com1': ['soybean oil'], 'com1_con': ['100 mg/mL'], 'com2': ['glycerol '], 'com2_con': ['22.5 mg/mL'], 'com3': ['egg lecithin '], 'com3_con': ['12 mg/mL'], 'com4': [''], 'com4_con': [''], 'com5': [''], 'com5_con': [''], 'ph': ['7 to 8.5.'], 'dosage': ['']}

# %%
import os
import sys
os.path.dirname(DailyMedScrape.ip)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-74caac364bd2> in <module>
#       1 import os
#       2 import sys
# ----> 3 os.path.dirname()
#
# TypeError: dirname() missing 1 required positional argument: 'p'
